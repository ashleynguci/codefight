# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df = pd.read_csv('pokemon_data.txt',delimiter="\t")
# print(df)

#print(df_xlsx.head(4))
#print(df.head(4))
#print(df.tail(4))

#Read header
# print(df.columns)

#Read column
# print(df['Name'])
# print(df['Speed'])
# print(df[['Name','HP',"Attack"]][0:5])


#Read row
# print(df.iloc[2:4])
# for index, row in df.iterrows():
#     print(index,row['Name'])
# df.loc[df['Type 1']=='Fire']

#Read a specific location(R,C)
# print(df.iloc[3,1])

#SORT/DESCRIBING
# df.describe()
# print(df.sort_values("HP",ascending = False))
# print(df.sort_values(["Type 1","HP"]))
# print(df.sort_values(["Type 1","HP"],ascending=[1,0]))
# Out:
#    #                   Name Type 1  Type 2  All  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  318  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  405  60      62       63       80
# 2  3               Venusaur  Grass  Poison  525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  625  80     100      123      122
# 4  4             Charmander   Fire     NaN  309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#MODIFY DATAFRAME

# df['SUM']=df['HP']+df['Attack']+df['Defense']
# df = df.drop(columns=['SUM'])
df['All']=df.iloc[:,4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head(5)
#Axis 0 will act on all the ROWS in each COLUMN
#Axis 1 will act on all the COLUMNS in each ROW
#So a SUM on axis 0 will be the SUM of all the rows in each column, and a SUM on axis 1 will be a SUM of all the columns in each row.
# Out:
#    #                   Name Type 1  Type 2  Legendary   All  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False   591  45      49
# 1  2                Ivysaur  Grass  Poison      False   750  60      62
# 2  3               Venusaur  Grass  Poison      False   970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  1170  80     100
# 4  4             Charmander   Fire     NaN      False   553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
# df.to_csv("modified.csv",index=False)
# df.to_excel("modified.xlsx",index=False)
df.to_csv("modified.txt",index=False,sep="\t")

# %%
#FILTER DATA
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')&(df['HP']>70)]
new_df = new_df.reset_index()
print(new_df)
new_df.to_csv("filter.txt", index=False, sep="\t")
# Out:
#    index    #                   Name Type 1  Type 2  Legendary   All   HP  \
# 0      2    3               Venusaur  Grass  Poison      False   970   80
# 1      3    3  VenusaurMega Venusaur  Grass  Poison      False  1170   80
# 2     50   45              Vileplume  Grass  Poison      False   930   75
# 3     77   71             Victreebel  Grass  Poison      False   910   80
# 4    652  591              Amoonguss  Grass  Poison      False   898  114
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      82       83      100      100     80           1
# 1     100      123      122      120     80           1
# 2      80       85      110       90     50           1
# 3     105       65      100       70     70           1
# 4      85       70       85       80     30           5

# %%
df.loc[~df['Name'].str.contains("Mega")]
# Out:
#        #                   Name    Type 1  Type 2  Legendary   All   HP  \
# 0      1              Bulbasaur     Grass  Poison      False   591   45
# 1      2                Ivysaur     Grass  Poison      False   750   60
# 2      3               Venusaur     Grass  Poison      False   970   80
# 4      4             Charmander      Fire     NaN      False   553   39
# 5      5             Charmeleon      Fire     NaN      False   730   58
# 6      6              Charizard      Fire  Flying      False   968   78
# 9      7               Squirtle     Water     NaN      False   585   44
# 10     8              Wartortle     Water     NaN      False   752   59
# 11     9              Blastoise     Water     NaN      False   982   79
# 13    10               Caterpie       Bug     NaN      False   345   45
# 14    11                Metapod       Bug     NaN      False   380   50
# 15    12             Butterfree       Bug  Flying      False   720   60
# 16    13                 Weedle       Bug  Poison      False   340   40
# 17    14                 Kakuna       Bug  Poison      False   375   45
# 18    15               Beedrill       Bug  Poison      False   715   65
# 20    16                 Pidgey    Normal  Flying      False   446   40
# 21    17              Pidgeotto    Normal  Flying      False   627   63
# 22    18                Pidgeot    Normal  Flying      False   857   83
# 24    19                Rattata    Normal     NaN      False   434   30
# 25    20               Raticate    Normal     NaN      False   729   55
# 26    21                Spearow    Normal  Flying      False   454   40
# 27    22                 Fearow    Normal  Flying      False   784   65
# 28    23                  Ekans    Poison     NaN      False   521   35
# 29    24                  Arbok    Poison     NaN      False   796   60
# 30    25                Pikachu  Electric     NaN      False   550   35
# 31    26                 Raichu  Electric     NaN      False   860   60
# 32    27              Sandshrew    Ground     NaN      False   560   50
# 33    28              Sandslash    Ground     NaN      False   835   75
# 34    29       Nidoran (Female)    Poison     NaN      False   509   55
# 35    30               Nidorina    Poison     NaN      False   674   70
# ..   ...                    ...       ...     ...        ...   ...  ...
# 769  699                Aurorus      Rock     Ice      False   984  123
# 770  700                Sylveon     Fairy     NaN      False   990   95
# 771  701               Hawlucha  Fighting  Flying      False   882   78
# 772  702                Dedenne  Electric   Fairy      False   761   67
# 773  703                Carbink      Rock   Fairy      False   950   50
# 774  704                  Goomy    Dragon     NaN      False   560   45
# 775  705                Sliggoo    Dragon     NaN      False   844   68
# 776  706                 Goodra    Dragon     NaN      False  1120   90
# 777  707                 Klefki     Steel   Fairy      False   865   57
# 778  708               Phantump     Ghost   Grass      False   580   43
# 779  709              Trevenant     Ghost   Grass      False   892   85
# 780  710  PumpkabooAverage Size     Ghost   Grass      False   619   49
# 781  710    PumpkabooSmall Size     Ghost   Grass      False   614   44
# 782  710    PumpkabooLarge Size     Ghost   Grass      False   624   54
# 783  710    PumpkabooSuper Size     Ghost   Grass      False   629   59
# 784  711  GourgeistAverage Size     Ghost   Grass      False   904   65
# 785  711    GourgeistSmall Size     Ghost   Grass      False   889   55
# 786  711    GourgeistLarge Size     Ghost   Grass      False   919   75
# 787  711    GourgeistSuper Size     Ghost   Grass      False   934   85
# 788  712               Bergmite       Ice     NaN      False   580   55
# 789  713                Avalugg       Ice     NaN      False  1000   95
# 790  714                 Noibat    Flying  Dragon      False   435   40
# 791  715                Noivern    Flying  Dragon      False   947   85
# 792  716                Xerneas     Fairy     NaN       True  1261  126
# 793  717                Yveltal      Dark  Flying       True  1261  126
# 794  718       Zygarde50% Forme    Dragon  Ground       True  1105  108
# 795  719                Diancie      Rock   Fairy       True  1150   50
# 797  720    HoopaHoopa Confined   Psychic   Ghost       True  1130   80
# 798  720     HoopaHoopa Unbound   Psychic    Dark       True  1280   80
# 799  721              Volcanion      Fire   Water       True  1130   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0        49       49       65       65     45           1
# 1        62       63       80       80     60           1
# 2        82       83      100      100     80           1
# 4        52       43       60       50     65           1
# 5        64       58       80       65     80           1
# 6        84       78      109       85    100           1
# 9        48       65       50       64     43           1
# 10       63       80       65       80     58           1
# 11       83      100       85      105     78           1
# 13       30       35       20       20     45           1
# 14       20       55       25       25     30           1
# 15       45       50       90       80     70           1
# 16       35       30       20       20     50           1
# 17       25       50       25       25     35           1
# 18       90       40       45       80     75           1
# 20       45       40       35       35     56           1
# 21       60       55       50       50     71           1
# 22       80       75       70       70    101           1
# 24       56       35       25       35     72           1
# 25       81       60       50       70     97           1
# 26       60       30       31       31     70           1
# 27       90       65       61       61    100           1
# 28       60       44       40       54     55           1
# 29       85       69       65       79     80           1
# 30       55       40       50       50     90           1
# 31       90       55       90       80    110           1
# 32       75       85       20       30     40           1
# 33      100      110       45       55     65           1
# 34       47       52       40       40     41           1
# 35       62       67       55       55     56           1
# ..      ...      ...      ...      ...    ...         ...
# 769      77       72       99       92     58           6
# 770      65       65      110      130     60           6
# 771      92       75       74       63    118           6
# 772      58       57       81       67    101           6
# 773      50      150       50      150     50           6
# 774      50       35       55       75     40           6
# 775      75       53       83      113     60           6
# 776     100       70      110      150     80           6
# 777      80       91       80       87     75           6
# 778      70       48       50       60     38           6
# 779     110       76       65       82     56           6
# 780      66       70       44       55     51           6
# 781      66       70       44       55     56           6
# 782      66       70       44       55     46           6
# 783      66       70       44       55     41           6
# 784      90      122       58       75     84           6
# 785      85      122       58       75     99           6
# 786      95      122       58       75     69           6
# 787     100      122       58       75     54           6
# 788      69       85       32       35     28           6
# 789     117      184       44       46     28           6
# 790      30       35       45       40     55           6
# 791      70       80       97       80    123           6
# 792     131       95      131       98     99           6
# 793     131       95      131       98     99           6
# 794     100      121       81       95     95           6
# 795     100      150      100      150     50           6
# 797     110       60      150      130     70           6
# 798     160       60      170      130     80           6
# 799     110      120      130       90     70           6
#
# [751 rows x 13 columns]

# %%
df.loc[df['Name'].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2  Legendary   All   HP  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      False  1170   80
# 7      6  CharizardMega Charizard X      Fire    Dragon      False  1168   78
# 8      6  CharizardMega Charizard Y      Fire    Flying      False  1168   78
# 12     9    BlastoiseMega Blastoise     Water       NaN      False  1182   79
# 19    15      BeedrillMega Beedrill       Bug    Poison      False   845   65
# 23    18        PidgeotMega Pidgeot    Normal    Flying      False  1037   83
# 71    65      AlakazamMega Alakazam   Psychic       NaN      False  1030   55
# 87    80        SlowbroMega Slowbro     Water   Psychic      False  1150   95
# 102   94          GengarMega Gengar     Ghost    Poison      False  1070   60
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      False  1080  105
# 137  127          PinsirMega Pinsir       Bug    Flying      False  1095   65
# 141  130      GyaradosMega Gyarados     Water      Dark      False  1199   95
# 154  142  AerodactylMega Aerodactyl      Rock    Flying      False  1080   80
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting       True  1430  106
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN       True  1420  106
# 168  154                   Meganium     Grass       NaN      False   970   80
# 196  181      AmpharosMega Ampharos  Electric    Dragon      False  1175   90
# 224  208        SteelixMega Steelix     Steel    Ground      False  1190   75
# 229  212          ScizorMega Scizor       Bug     Steel      False  1125   70
# 232  214    HeracrossMega Heracross       Bug  Fighting      False  1125   80
# 248  229      HoundoomMega Houndoom      Dark      Fire      False  1085   75
# 268  248    TyranitarMega Tyranitar      Rock      Dark      False  1329  100
# 275  254      SceptileMega Sceptile     Grass    Dragon      False  1115   70
# 279  257      BlazikenMega Blaziken      Fire  Fighting      False  1160   80
# 283  260      SwampertMega Swampert     Water    Ground      False  1200  100
# 306  282    GardevoirMega Gardevoir   Psychic     Fairy      False  1136   68
# 327  302        SableyeMega Sableye      Dark     Ghost      False   940   50
# 329  303          MawileMega Mawile     Steel     Fairy      False   910   50
# 333  306          AggronMega Aggron     Steel       NaN      False  1210   70
# 336  308      MedichamMega Medicham  Fighting   Psychic      False   920   60
# 339  310    ManectricMega Manectric  Electric       NaN      False  1015   70
# 349  319      SharpedoMega Sharpedo     Water      Dark      False  1015   70
# 354  323      CameruptMega Camerupt      Fire    Ground      False  1100   70
# 366  334        AltariaMega Altaria    Dragon     Fairy      False  1100   75
# 387  354        BanetteMega Banette     Ghost       NaN      False  1035   64
# 393  359            AbsolMega Absol      Dark       NaN      False  1015   65
# 397  362          GlalieMega Glalie       Ice       NaN      False  1060   80
# 409  373    SalamenceMega Salamence    Dragon    Flying      False  1280   95
# 413  376    MetagrossMega Metagross     Steel   Psychic      False  1290   80
# 418  380          LatiasMega Latias    Dragon   Psychic       True  1290   80
# 420  381          LatiosMega Latios    Dragon   Psychic       True  1290   80
# 426  384      RayquazaMega Rayquaza    Dragon    Flying       True  1445  105
# 476  428        LopunnyMega Lopunny    Normal  Fighting      False  1025   65
# 494  445      GarchompMega Garchomp    Dragon    Ground      False  1308  108
# 498  448        LucarioMega Lucario  Fighting     Steel      False  1138   70
# 511  460    AbomasnowMega Abomasnow     Grass       Ice      False  1158   90
# 527  475        GalladeMega Gallade   Psychic  Fighting      False  1126   68
# 591  531          AudinoMega Audino    Normal     Fairy      False  1040  103
# 796  719        DiancieMega Diancie      Rock     Fairy       True  1290   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 3       100      123      122      120     80           1
# 7       130      111      130       85    100           1
# 8       104       78      159      115    100           1
# 12      103      120      135      115     78           1
# 19      150       40       15       80    145           1
# 23       80       80      135       80    121           1
# 71       50       65      175       95    150           1
# 87       75      180      130       80     30           1
# 102      65       80      170       95    130           1
# 124     125      100       60      100    100           1
# 137     155      120       65       90    105           1
# 141     155      109       70      130     81           1
# 154     135       85       70       95    150           1
# 163     190      100      154      100    130           1
# 164     150       70      194      120    140           1
# 168      82      100       83      100     80           2
# 196      95      105      165      110     45           2
# 224     125      230       55       95     30           2
# 229     150      140       65      100     75           2
# 232     185      115       40      105     75           2
# 248      90       90      140       90    115           2
# 268     164      150       95      120     71           2
# 275     110       75      145       85    145           3
# 279     160       80      130       80    100           3
# 283     150      110       95      110     70           3
# 306      85       65      165      135    100           3
# 327      85      125       85      115     20           3
# 329     105      125       55       95     50           3
# 333     140      230       60       80     50           3
# 336     100       85       80       85    100           3
# 339      75       80      135       80    135           3
# 349     140       70      110       65    105           3
# 354     120      100      145      105     20           3
# 366     110      110      110      105     80           3
# 387     165       75       93       83     75           3
# 393     150       60      115       60    115           3
# 397     120       80      120       80    100           3
# 409     145      130      120       90    120           3
# 413     145      150      105      110    110           3
# 418     100      120      140      150    110           3
# 420     130      100      160      120    110           3
# 426     180      100      180      100    115           3
# 476     136       94       54       96    135           4
# 494     170      115      120       95     92           4
# 498     145       88      140       70    112           4
# 511     132      105      132      105     30           4
# 527     165       95       65      115    110           4
# 591      60      126       80      126     50           5
# 796     160      110      160      110    110           6

# %%
##FILTER BASED ON TEXTURE PATTERN

import re
# df.loc[df['Type 1'].str.contains(('Grass|Fire'), regex= True)]
# df.loc[df['Type 1'].str.contains(('grass|fire'), flags = re.I,regex= True)]
df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I,regex= True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary   All   HP  \
# 20    16               Pidgey    Normal    Flying      False   446   40
# 21    17            Pidgeotto    Normal    Flying      False   627   63
# 22    18              Pidgeot    Normal    Flying      False   857   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False  1037   83
# 30    25              Pikachu  Electric       NaN      False   550   35
# 136  127               Pinsir       Bug       NaN      False   915   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False  1095   65
# 186  172                Pichu  Electric       NaN      False   350   20
# 219  204               Pineco       Bug       NaN      False   565   50
# 239  221            Piloswine       Ice    Ground      False   850  100
# 438  393               Piplup     Water       NaN      False   588   53
# 558  499              Pignite      Fire  Fighting      False   781   90
# 578  519               Pidove    Normal    Flying      False   485   50
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 20       45       40       35       35     56           1
# 21       60       55       50       50     71           1
# 22       80       75       70       70    101           1
# 23       80       80      135       80    121           1
# 30       55       40       50       50     90           1
# 136     125      100       55       70     85           1
# 137     155      120       65       90    105           1
# 186      40       15       35       35     60           2
# 219      65       90       35       35     15           2
# 239     100       80       60       60     50           2
# 438      51       53       61       56     40           4
# 558      93       55       70       55     55           5
# 578      55       50       36       30     43           5

# %%
df.loc[df['Type 1']=='Fire', 'Legendary']=True

# %%
df.loc[df['Type 1']=='Fla', 'Type 1']='Fire'
df
# Out:
#        #                       Name    Type 1  Type 2  Legendary   All   HP  \
# 0      1                  Bulbasaur     Grass  Poison      False   591   45
# 1      2                    Ivysaur     Grass  Poison      False   750   60
# 2      3                   Venusaur     Grass  Poison      False   970   80
# 3      3      VenusaurMega Venusaur     Grass  Poison      False  1170   80
# 4      4                 Charmander      Fire     NaN       True   553   39
# 5      5                 Charmeleon      Fire     NaN       True   730   58
# 6      6                  Charizard      Fire  Flying       True   968   78
# 7      6  CharizardMega Charizard X      Fire  Dragon       True  1168   78
# 8      6  CharizardMega Charizard Y      Fire  Flying       True  1168   78
# 9      7                   Squirtle     Water     NaN      False   585   44
# 10     8                  Wartortle     Water     NaN      False   752   59
# 11     9                  Blastoise     Water     NaN      False   982   79
# 12     9    BlastoiseMega Blastoise     Water     NaN      False  1182   79
# 13    10                   Caterpie       Bug     NaN      False   345   45
# 14    11                    Metapod       Bug     NaN      False   380   50
# 15    12                 Butterfree       Bug  Flying      False   720   60
# 16    13                     Weedle       Bug  Poison      False   340   40
# 17    14                     Kakuna       Bug  Poison      False   375   45
# 18    15                   Beedrill       Bug  Poison      False   715   65
# 19    15      BeedrillMega Beedrill       Bug  Poison      False   845   65
# 20    16                     Pidgey    Normal  Flying      False   446   40
# 21    17                  Pidgeotto    Normal  Flying      False   627   63
# 22    18                    Pidgeot    Normal  Flying      False   857   83
# 23    18        PidgeotMega Pidgeot    Normal  Flying      False  1037   83
# 24    19                    Rattata    Normal     NaN      False   434   30
# 25    20                   Raticate    Normal     NaN      False   729   55
# 26    21                    Spearow    Normal  Flying      False   454   40
# 27    22                     Fearow    Normal  Flying      False   784   65
# 28    23                      Ekans    Poison     NaN      False   521   35
# 29    24                      Arbok    Poison     NaN      False   796   60
# ..   ...                        ...       ...     ...        ...   ...  ...
# 770  700                    Sylveon     Fairy     NaN      False   990   95
# 771  701                   Hawlucha  Fighting  Flying      False   882   78
# 772  702                    Dedenne  Electric   Fairy      False   761   67
# 773  703                    Carbink      Rock   Fairy      False   950   50
# 774  704                      Goomy    Dragon     NaN      False   560   45
# 775  705                    Sliggoo    Dragon     NaN      False   844   68
# 776  706                     Goodra    Dragon     NaN      False  1120   90
# 777  707                     Klefki     Steel   Fairy      False   865   57
# 778  708                   Phantump     Ghost   Grass      False   580   43
# 779  709                  Trevenant     Ghost   Grass      False   892   85
# 780  710      PumpkabooAverage Size     Ghost   Grass      False   619   49
# 781  710        PumpkabooSmall Size     Ghost   Grass      False   614   44
# 782  710        PumpkabooLarge Size     Ghost   Grass      False   624   54
# 783  710        PumpkabooSuper Size     Ghost   Grass      False   629   59
# 784  711      GourgeistAverage Size     Ghost   Grass      False   904   65
# 785  711        GourgeistSmall Size     Ghost   Grass      False   889   55
# 786  711        GourgeistLarge Size     Ghost   Grass      False   919   75
# 787  711        GourgeistSuper Size     Ghost   Grass      False   934   85
# 788  712                   Bergmite       Ice     NaN      False   580   55
# 789  713                    Avalugg       Ice     NaN      False  1000   95
# 790  714                     Noibat    Flying  Dragon      False   435   40
# 791  715                    Noivern    Flying  Dragon      False   947   85
# 792  716                    Xerneas     Fairy     NaN       True  1261  126
# 793  717                    Yveltal      Dark  Flying       True  1261  126
# 794  718           Zygarde50% Forme    Dragon  Ground       True  1105  108
# 795  719                    Diancie      Rock   Fairy       True  1150   50
# 796  719        DiancieMega Diancie      Rock   Fairy       True  1290   50
# 797  720        HoopaHoopa Confined   Psychic   Ghost       True  1130   80
# 798  720         HoopaHoopa Unbound   Psychic    Dark       True  1280   80
# 799  721                  Volcanion      Fire   Water       True  1130   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0        49       49       65       65     45           1
# 1        62       63       80       80     60           1
# 2        82       83      100      100     80           1
# 3       100      123      122      120     80           1
# 4        52       43       60       50     65           1
# 5        64       58       80       65     80           1
# 6        84       78      109       85    100           1
# 7       130      111      130       85    100           1
# 8       104       78      159      115    100           1
# 9        48       65       50       64     43           1
# 10       63       80       65       80     58           1
# 11       83      100       85      105     78           1
# 12      103      120      135      115     78           1
# 13       30       35       20       20     45           1
# 14       20       55       25       25     30           1
# 15       45       50       90       80     70           1
# 16       35       30       20       20     50           1
# 17       25       50       25       25     35           1
# 18       90       40       45       80     75           1
# 19      150       40       15       80    145           1
# 20       45       40       35       35     56           1
# 21       60       55       50       50     71           1
# 22       80       75       70       70    101           1
# 23       80       80      135       80    121           1
# 24       56       35       25       35     72           1
# 25       81       60       50       70     97           1
# 26       60       30       31       31     70           1
# 27       90       65       61       61    100           1
# 28       60       44       40       54     55           1
# 29       85       69       65       79     80           1
# ..      ...      ...      ...      ...    ...         ...
# 770      65       65      110      130     60           6
# 771      92       75       74       63    118           6
# 772      58       57       81       67    101           6
# 773      50      150       50      150     50           6
# 774      50       35       55       75     40           6
# 775      75       53       83      113     60           6
# 776     100       70      110      150     80           6
# 777      80       91       80       87     75           6
# 778      70       48       50       60     38           6
# 779     110       76       65       82     56           6
# 780      66       70       44       55     51           6
# 781      66       70       44       55     56           6
# 782      66       70       44       55     46           6
# 783      66       70       44       55     41           6
# 784      90      122       58       75     84           6
# 785      85      122       58       75     99           6
# 786      95      122       58       75     69           6
# 787     100      122       58       75     54           6
# 788      69       85       32       35     28           6
# 789     117      184       44       46     28           6
# 790      30       35       45       40     55           6
# 791      70       80       97       80    123           6
# 792     131       95      131       98     99           6
# 793     131       95      131       98     99           6
# 794     100      121       81       95     95           6
# 795     100      150      100      150     50           6
# 796     160      110      160      110    110           6
# 797     110       60      150      130     70           6
# 798     160       60      170      130     80           6
# 799     110      120      130       90     70           6
#
# [800 rows x 13 columns]

# %%
df.loc[df['All'] > 1000,['Generation','Legendary']]='ERROR'
df
# Out:
#        #                       Name    Type 1  Type 2 Legendary   All   HP  \
# 0      1                  Bulbasaur     Grass  Poison     False   591   45
# 1      2                    Ivysaur     Grass  Poison     False   750   60
# 2      3                   Venusaur     Grass  Poison     False   970   80
# 3      3      VenusaurMega Venusaur     Grass  Poison     ERROR  1170   80
# 4      4                 Charmander      Fire     NaN      True   553   39
# 5      5                 Charmeleon      Fire     NaN      True   730   58
# 6      6                  Charizard      Fire  Flying      True   968   78
# 7      6  CharizardMega Charizard X      Fire  Dragon     ERROR  1168   78
# 8      6  CharizardMega Charizard Y      Fire  Flying     ERROR  1168   78
# 9      7                   Squirtle     Water     NaN     False   585   44
# 10     8                  Wartortle     Water     NaN     False   752   59
# 11     9                  Blastoise     Water     NaN     False   982   79
# 12     9    BlastoiseMega Blastoise     Water     NaN     ERROR  1182   79
# 13    10                   Caterpie       Bug     NaN     False   345   45
# 14    11                    Metapod       Bug     NaN     False   380   50
# 15    12                 Butterfree       Bug  Flying     False   720   60
# 16    13                     Weedle       Bug  Poison     False   340   40
# 17    14                     Kakuna       Bug  Poison     False   375   45
# 18    15                   Beedrill       Bug  Poison     False   715   65
# 19    15      BeedrillMega Beedrill       Bug  Poison     False   845   65
# 20    16                     Pidgey    Normal  Flying     False   446   40
# 21    17                  Pidgeotto    Normal  Flying     False   627   63
# 22    18                    Pidgeot    Normal  Flying     False   857   83
# 23    18        PidgeotMega Pidgeot    Normal  Flying     ERROR  1037   83
# 24    19                    Rattata    Normal     NaN     False   434   30
# 25    20                   Raticate    Normal     NaN     False   729   55
# 26    21                    Spearow    Normal  Flying     False   454   40
# 27    22                     Fearow    Normal  Flying     False   784   65
# 28    23                      Ekans    Poison     NaN     False   521   35
# 29    24                      Arbok    Poison     NaN     False   796   60
# ..   ...                        ...       ...     ...       ...   ...  ...
# 770  700                    Sylveon     Fairy     NaN     False   990   95
# 771  701                   Hawlucha  Fighting  Flying     False   882   78
# 772  702                    Dedenne  Electric   Fairy     False   761   67
# 773  703                    Carbink      Rock   Fairy     False   950   50
# 774  704                      Goomy    Dragon     NaN     False   560   45
# 775  705                    Sliggoo    Dragon     NaN     False   844   68
# 776  706                     Goodra    Dragon     NaN     ERROR  1120   90
# 777  707                     Klefki     Steel   Fairy     False   865   57
# 778  708                   Phantump     Ghost   Grass     False   580   43
# 779  709                  Trevenant     Ghost   Grass     False   892   85
# 780  710      PumpkabooAverage Size     Ghost   Grass     False   619   49
# 781  710        PumpkabooSmall Size     Ghost   Grass     False   614   44
# 782  710        PumpkabooLarge Size     Ghost   Grass     False   624   54
# 783  710        PumpkabooSuper Size     Ghost   Grass     False   629   59
# 784  711      GourgeistAverage Size     Ghost   Grass     False   904   65
# 785  711        GourgeistSmall Size     Ghost   Grass     False   889   55
# 786  711        GourgeistLarge Size     Ghost   Grass     False   919   75
# 787  711        GourgeistSuper Size     Ghost   Grass     False   934   85
# 788  712                   Bergmite       Ice     NaN     False   580   55
# 789  713                    Avalugg       Ice     NaN     False  1000   95
# 790  714                     Noibat    Flying  Dragon     False   435   40
# 791  715                    Noivern    Flying  Dragon     False   947   85
# 792  716                    Xerneas     Fairy     NaN     ERROR  1261  126
# 793  717                    Yveltal      Dark  Flying     ERROR  1261  126
# 794  718           Zygarde50% Forme    Dragon  Ground     ERROR  1105  108
# 795  719                    Diancie      Rock   Fairy     ERROR  1150   50
# 796  719        DiancieMega Diancie      Rock   Fairy     ERROR  1290   50
# 797  720        HoopaHoopa Confined   Psychic   Ghost     ERROR  1130   80
# 798  720         HoopaHoopa Unbound   Psychic    Dark     ERROR  1280   80
# 799  721                  Volcanion      Fire   Water     ERROR  1130   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed Generation
# 0        49       49       65       65     45          1
# 1        62       63       80       80     60          1
# 2        82       83      100      100     80          1
# 3       100      123      122      120     80      ERROR
# 4        52       43       60       50     65          1
# 5        64       58       80       65     80          1
# 6        84       78      109       85    100          1
# 7       130      111      130       85    100      ERROR
# 8       104       78      159      115    100      ERROR
# 9        48       65       50       64     43          1
# 10       63       80       65       80     58          1
# 11       83      100       85      105     78          1
# 12      103      120      135      115     78      ERROR
# 13       30       35       20       20     45          1
# 14       20       55       25       25     30          1
# 15       45       50       90       80     70          1
# 16       35       30       20       20     50          1
# 17       25       50       25       25     35          1
# 18       90       40       45       80     75          1
# 19      150       40       15       80    145          1
# 20       45       40       35       35     56          1
# 21       60       55       50       50     71          1
# 22       80       75       70       70    101          1
# 23       80       80      135       80    121      ERROR
# 24       56       35       25       35     72          1
# 25       81       60       50       70     97          1
# 26       60       30       31       31     70          1
# 27       90       65       61       61    100          1
# 28       60       44       40       54     55          1
# 29       85       69       65       79     80          1
# ..      ...      ...      ...      ...    ...        ...
# 770      65       65      110      130     60          6
# 771      92       75       74       63    118          6
# 772      58       57       81       67    101          6
# 773      50      150       50      150     50          6
# 774      50       35       55       75     40          6
# 775      75       53       83      113     60          6
# 776     100       70      110      150     80      ERROR
# 777      80       91       80       87     75          6
# 778      70       48       50       60     38          6
# 779     110       76       65       82     56          6
# 780      66       70       44       55     51          6
# 781      66       70       44       55     56          6
# 782      66       70       44       55     46          6
# 783      66       70       44       55     41          6
# 784      90      122       58       75     84          6
# 785      85      122       58       75     99          6
# 786      95      122       58       75     69          6
# 787     100      122       58       75     54          6
# 788      69       85       32       35     28          6
# 789     117      184       44       46     28          6
# 790      30       35       45       40     55          6
# 791      70       80       97       80    123          6
# 792     131       95      131       98     99      ERROR
# 793     131       95      131       98     99      ERROR
# 794     100      121       81       95     95      ERROR
# 795     100      150      100      150     50      ERROR
# 796     160      110      160      110    110      ERROR
# 797     110       60      150      130     70      ERROR
# 798     160       60      170      130     80      ERROR
# 799     110      120      130       90     70      ERROR
#
# [800 rows x 13 columns]

# %%
df.loc[df['All'] > 1000,['Generation','Legendary']]=['ERROR', 'OK']
df
# Out:
#        #                       Name    Type 1  Type 2 Legendary   All   HP  \
# 0      1                  Bulbasaur     Grass  Poison     False   591   45
# 1      2                    Ivysaur     Grass  Poison     False   750   60
# 2      3                   Venusaur     Grass  Poison     False   970   80
# 3      3      VenusaurMega Venusaur     Grass  Poison        OK  1170   80
# 4      4                 Charmander      Fire     NaN      True   553   39
# 5      5                 Charmeleon      Fire     NaN      True   730   58
# 6      6                  Charizard      Fire  Flying      True   968   78
# 7      6  CharizardMega Charizard X      Fire  Dragon        OK  1168   78
# 8      6  CharizardMega Charizard Y      Fire  Flying        OK  1168   78
# 9      7                   Squirtle     Water     NaN     False   585   44
# 10     8                  Wartortle     Water     NaN     False   752   59
# 11     9                  Blastoise     Water     NaN     False   982   79
# 12     9    BlastoiseMega Blastoise     Water     NaN        OK  1182   79
# 13    10                   Caterpie       Bug     NaN     False   345   45
# 14    11                    Metapod       Bug     NaN     False   380   50
# 15    12                 Butterfree       Bug  Flying     False   720   60
# 16    13                     Weedle       Bug  Poison     False   340   40
# 17    14                     Kakuna       Bug  Poison     False   375   45
# 18    15                   Beedrill       Bug  Poison     False   715   65
# 19    15      BeedrillMega Beedrill       Bug  Poison     False   845   65
# 20    16                     Pidgey    Normal  Flying     False   446   40
# 21    17                  Pidgeotto    Normal  Flying     False   627   63
# 22    18                    Pidgeot    Normal  Flying     False   857   83
# 23    18        PidgeotMega Pidgeot    Normal  Flying        OK  1037   83
# 24    19                    Rattata    Normal     NaN     False   434   30
# 25    20                   Raticate    Normal     NaN     False   729   55
# 26    21                    Spearow    Normal  Flying     False   454   40
# 27    22                     Fearow    Normal  Flying     False   784   65
# 28    23                      Ekans    Poison     NaN     False   521   35
# 29    24                      Arbok    Poison     NaN     False   796   60
# ..   ...                        ...       ...     ...       ...   ...  ...
# 770  700                    Sylveon     Fairy     NaN     False   990   95
# 771  701                   Hawlucha  Fighting  Flying     False   882   78
# 772  702                    Dedenne  Electric   Fairy     False   761   67
# 773  703                    Carbink      Rock   Fairy     False   950   50
# 774  704                      Goomy    Dragon     NaN     False   560   45
# 775  705                    Sliggoo    Dragon     NaN     False   844   68
# 776  706                     Goodra    Dragon     NaN        OK  1120   90
# 777  707                     Klefki     Steel   Fairy     False   865   57
# 778  708                   Phantump     Ghost   Grass     False   580   43
# 779  709                  Trevenant     Ghost   Grass     False   892   85
# 780  710      PumpkabooAverage Size     Ghost   Grass     False   619   49
# 781  710        PumpkabooSmall Size     Ghost   Grass     False   614   44
# 782  710        PumpkabooLarge Size     Ghost   Grass     False   624   54
# 783  710        PumpkabooSuper Size     Ghost   Grass     False   629   59
# 784  711      GourgeistAverage Size     Ghost   Grass     False   904   65
# 785  711        GourgeistSmall Size     Ghost   Grass     False   889   55
# 786  711        GourgeistLarge Size     Ghost   Grass     False   919   75
# 787  711        GourgeistSuper Size     Ghost   Grass     False   934   85
# 788  712                   Bergmite       Ice     NaN     False   580   55
# 789  713                    Avalugg       Ice     NaN     False  1000   95
# 790  714                     Noibat    Flying  Dragon     False   435   40
# 791  715                    Noivern    Flying  Dragon     False   947   85
# 792  716                    Xerneas     Fairy     NaN        OK  1261  126
# 793  717                    Yveltal      Dark  Flying        OK  1261  126
# 794  718           Zygarde50% Forme    Dragon  Ground        OK  1105  108
# 795  719                    Diancie      Rock   Fairy        OK  1150   50
# 796  719        DiancieMega Diancie      Rock   Fairy        OK  1290   50
# 797  720        HoopaHoopa Confined   Psychic   Ghost        OK  1130   80
# 798  720         HoopaHoopa Unbound   Psychic    Dark        OK  1280   80
# 799  721                  Volcanion      Fire   Water        OK  1130   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed Generation
# 0        49       49       65       65     45          1
# 1        62       63       80       80     60          1
# 2        82       83      100      100     80          1
# 3       100      123      122      120     80      ERROR
# 4        52       43       60       50     65          1
# 5        64       58       80       65     80          1
# 6        84       78      109       85    100          1
# 7       130      111      130       85    100      ERROR
# 8       104       78      159      115    100      ERROR
# 9        48       65       50       64     43          1
# 10       63       80       65       80     58          1
# 11       83      100       85      105     78          1
# 12      103      120      135      115     78      ERROR
# 13       30       35       20       20     45          1
# 14       20       55       25       25     30          1
# 15       45       50       90       80     70          1
# 16       35       30       20       20     50          1
# 17       25       50       25       25     35          1
# 18       90       40       45       80     75          1
# 19      150       40       15       80    145          1
# 20       45       40       35       35     56          1
# 21       60       55       50       50     71          1
# 22       80       75       70       70    101          1
# 23       80       80      135       80    121      ERROR
# 24       56       35       25       35     72          1
# 25       81       60       50       70     97          1
# 26       60       30       31       31     70          1
# 27       90       65       61       61    100          1
# 28       60       44       40       54     55          1
# 29       85       69       65       79     80          1
# ..      ...      ...      ...      ...    ...        ...
# 770      65       65      110      130     60          6
# 771      92       75       74       63    118          6
# 772      58       57       81       67    101          6
# 773      50      150       50      150     50          6
# 774      50       35       55       75     40          6
# 775      75       53       83      113     60          6
# 776     100       70      110      150     80      ERROR
# 777      80       91       80       87     75          6
# 778      70       48       50       60     38          6
# 779     110       76       65       82     56          6
# 780      66       70       44       55     51          6
# 781      66       70       44       55     56          6
# 782      66       70       44       55     46          6
# 783      66       70       44       55     41          6
# 784      90      122       58       75     84          6
# 785      85      122       58       75     99          6
# 786      95      122       58       75     69          6
# 787     100      122       58       75     54          6
# 788      69       85       32       35     28          6
# 789     117      184       44       46     28          6
# 790      30       35       45       40     55          6
# 791      70       80       97       80    123          6
# 792     131       95      131       98     99      ERROR
# 793     131       95      131       98     99      ERROR
# 794     100      121       81       95     95      ERROR
# 795     100      150      100      150     50      ERROR
# 796     160      110      160      110    110      ERROR
# 797     110       60      150      130     70      ERROR
# 798     160       60      170      130     80      ERROR
# 799     110      120      130       90     70      ERROR
#
# [800 rows x 13 columns]

# %%
df = pd.read_csv('pokemon_data.csv')
df.groupby
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# 11     9                  Blastoise     Water     NaN   79      83      100
# 12     9    BlastoiseMega Blastoise     Water     NaN   79     103      120
# 13    10                   Caterpie       Bug     NaN   45      30       35
# 14    11                    Metapod       Bug     NaN   50      20       55
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 16    13                     Weedle       Bug  Poison   40      35       30
# 17    14                     Kakuna       Bug  Poison   45      25       50
# 18    15                   Beedrill       Bug  Poison   65      90       40
# 19    15      BeedrillMega Beedrill       Bug  Poison   65     150       40
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# 22    18                    Pidgeot    Normal  Flying   83      80       75
# 23    18        PidgeotMega Pidgeot    Normal  Flying   83      80       80
# 24    19                    Rattata    Normal     NaN   30      56       35
# 25    20                   Raticate    Normal     NaN   55      81       60
# 26    21                    Spearow    Normal  Flying   40      60       30
# 27    22                     Fearow    Normal  Flying   65      90       65
# 28    23                      Ekans    Poison     NaN   35      60       44
# 29    24                      Arbok    Poison     NaN   60      85       69
# ..   ...                        ...       ...     ...  ...     ...      ...
# 770  700                    Sylveon     Fairy     NaN   95      65       65
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 772  702                    Dedenne  Electric   Fairy   67      58       57
# 773  703                    Carbink      Rock   Fairy   50      50      150
# 774  704                      Goomy    Dragon     NaN   45      50       35
# 775  705                    Sliggoo    Dragon     NaN   68      75       53
# 776  706                     Goodra    Dragon     NaN   90     100       70
# 777  707                     Klefki     Steel   Fairy   57      80       91
# 778  708                   Phantump     Ghost   Grass   43      70       48
# 779  709                  Trevenant     Ghost   Grass   85     110       76
# 780  710      PumpkabooAverage Size     Ghost   Grass   49      66       70
# 781  710        PumpkabooSmall Size     Ghost   Grass   44      66       70
# 782  710        PumpkabooLarge Size     Ghost   Grass   54      66       70
# 783  710        PumpkabooSuper Size     Ghost   Grass   59      66       70
# 784  711      GourgeistAverage Size     Ghost   Grass   65      90      122
# 785  711        GourgeistSmall Size     Ghost   Grass   55      85      122
# 786  711        GourgeistLarge Size     Ghost   Grass   75      95      122
# 787  711        GourgeistSuper Size     Ghost   Grass   85     100      122
# 788  712                   Bergmite       Ice     NaN   55      69       85
# 789  713                    Avalugg       Ice     NaN   95     117      184
# 790  714                     Noibat    Flying  Dragon   40      30       35
# 791  715                    Noivern    Flying  Dragon   85      70       80
# 792  716                    Xerneas     Fairy     NaN  126     131       95
# 793  717                    Yveltal      Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme    Dragon  Ground  108     100      121
# 795  719                    Diancie      Rock   Fairy   50     100      150
# 796  719        DiancieMega Diancie      Rock   Fairy   50     160      110
# 797  720        HoopaHoopa Confined   Psychic   Ghost   80     110       60
# 798  720         HoopaHoopa Unbound   Psychic    Dark   80     160       60
# 799  721                  Volcanion      Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# 5         80       65     80           1      False
# 6        109       85    100           1      False
# 7        130       85    100           1      False
# 8        159      115    100           1      False
# 9         50       64     43           1      False
# 10        65       80     58           1      False
# 11        85      105     78           1      False
# 12       135      115     78           1      False
# 13        20       20     45           1      False
# 14        25       25     30           1      False
# 15        90       80     70           1      False
# 16        20       20     50           1      False
# 17        25       25     35           1      False
# 18        45       80     75           1      False
# 19        15       80    145           1      False
# 20        35       35     56           1      False
# 21        50       50     71           1      False
# 22        70       70    101           1      False
# 23       135       80    121           1      False
# 24        25       35     72           1      False
# 25        50       70     97           1      False
# 26        31       31     70           1      False
# 27        61       61    100           1      False
# 28        40       54     55           1      False
# 29        65       79     80           1      False
# ..       ...      ...    ...         ...        ...
# 770      110      130     60           6      False
# 771       74       63    118           6      False
# 772       81       67    101           6      False
# 773       50      150     50           6      False
# 774       55       75     40           6      False
# 775       83      113     60           6      False
# 776      110      150     80           6      False
# 777       80       87     75           6      False
# 778       50       60     38           6      False
# 779       65       82     56           6      False
# 780       44       55     51           6      False
# 781       44       55     56           6      False
# 782       44       55     46           6      False
# 783       44       55     41           6      False
# 784       58       75     84           6      False
# 785       58       75     99           6      False
# 786       58       75     69           6      False
# 787       58       75     54           6      False
# 788       32       35     28           6      False
# 789       44       46     28           6      False
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]
