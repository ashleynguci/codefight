# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y =[2,4,8]
z = [1,5,13]
plt.plot(x,y)
plt.plot(x,z)
plt.title("test")
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(['y','z'])
plt.show()

# %%
df = pd.read_csv('pokemon_data.csv')
print(df.head(4))
type(df)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# pandas.core.frame.DataFrame

# %%
type(df['HP'])
# Out:
# pandas.core.series.Series

# %%
plt.plot(df['HP'],df['Attack'])
# plt.plot(df['HP'],df['Defense'])
plt.show()

# %%
water = df[df['Type 1']=='Water']
fire = df[df['Type 1']=='Fire']

# %%
plt.plot(water.Attack,water.Defense)
plt.plot(fire.Attack,fire.Defense)

plt.xlabel('Attack')
plt.ylabel('Defense')
plt.legend(["Water","Fire"])
plt.show()
