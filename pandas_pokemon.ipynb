# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# df = pd.read_csv('pokemon_data.txt',delimiter="\t")
# print(df)

#print(df_xlsx.head(4))
#print(df.head(4))
#print(df.tail(4))

#Read header
# print(df.columns)

#Read column
# print(df['Name'])
# print(df['Speed'])
# print(df[['Name','HP',"Attack"]][0:5])


#Read row
# print(df.iloc[2:4])
# for index, row in df.iterrows():
#     print(index,row['Name'])
# df.loc[df['Type 1']=='Fire']

#Read a specific location(R,C)
# print(df.iloc[3,1])

#SORT/DESCRIBING
# df.describe()
# print(df.sort_values("HP",ascending = False))
# print(df.sort_values(["Type 1","HP"]))
# print(df.sort_values(["Type 1","HP"],ascending=[1,0]))
# Out:
#    #                   Name Type 1  Type 2  All  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  318  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  405  60      62       63       80
# 2  3               Venusaur  Grass  Poison  525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  625  80     100      123      122
# 4  4             Charmander   Fire     NaN  309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#MODIFY DATAFRAME

# df['SUM']=df['HP']+df['Attack']+df['Defense']
# df = df.drop(columns=['SUM'])
df['All']=df.iloc[:,4:10].sum(axis=1)

cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head(5)
#Axis 0 will act on all the ROWS in each COLUMN
#Axis 1 will act on all the COLUMNS in each ROW
#So a SUM on axis 0 will be the SUM of all the rows in each column, and a SUM on axis 1 will be a SUM of all the columns in each row.
# Out:
#    #                   Name Type 1  Type 2  Legendary   All  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False   591  45      49
# 1  2                Ivysaur  Grass  Poison      False   750  60      62
# 2  3               Venusaur  Grass  Poison      False   970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  1170  80     100
# 4  4             Charmander   Fire     NaN      False   553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1

# %%
# df.to_csv("modified.csv",index=False)
# df.to_excel("modified.xlsx",index=False)
df.to_csv("modified.txt",index=False,sep="\t")

# %%
#FILTER DATA
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')&(df['HP']>70)]
new_df = new_df.reset_index()
print(new_df)
new_df.to_csv("filter.txt", index=False, sep="\t")
# Out:
#    index    #                   Name Type 1  Type 2  Legendary   All   HP  \
# 0      2    3               Venusaur  Grass  Poison      False   970   80
# 1      3    3  VenusaurMega Venusaur  Grass  Poison      False  1170   80
# 2     50   45              Vileplume  Grass  Poison      False   930   75
# 3     77   71             Victreebel  Grass  Poison      False   910   80
# 4    652  591              Amoonguss  Grass  Poison      False   898  114
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      82       83      100      100     80           1
# 1     100      123      122      120     80           1
# 2      80       85      110       90     50           1
# 3     105       65      100       70     70           1
# 4      85       70       85       80     30           5

# %%
df.loc[~df['Name'].str.contains("Mega")]
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.loc[df['Name'].str.contains("Mega")]
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
##FILTER BASED ON TEXTURE PATTERN

import re
# df.loc[df['Type 1'].str.contains(('Grass|Fire'), regex= True)]
# df.loc[df['Type 1'].str.contains(('grass|fire'), flags = re.I,regex= True)]
df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I,regex= True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary   All   HP  \
# 20    16               Pidgey    Normal    Flying      False   446   40
# 21    17            Pidgeotto    Normal    Flying      False   627   63
# 22    18              Pidgeot    Normal    Flying      False   857   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False  1037   83
# 30    25              Pikachu  Electric       NaN      False   550   35
# 136  127               Pinsir       Bug       NaN      False   915   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False  1095   65
# 186  172                Pichu  Electric       NaN      False   350   20
# 219  204               Pineco       Bug       NaN      False   565   50
# 239  221            Piloswine       Ice    Ground      False   850  100
# 438  393               Piplup     Water       NaN      False   588   53
# 558  499              Pignite      Fire  Fighting      False   781   90
# ...

# %%
df.loc[df['Type 1']=='Fire', 'Legendary']=True

# %%
df.loc[df['Type 1']=='Fla', 'Type 1']='Fire'
df.head(4)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# df.loc[df['All'] > 1000,['Generation','Legendary']]='ERROR'
# df.head(4)

# %%
# df.loc[df['All'] > 1000,['Generation','Legendary']]=['ERROR', 'OK']
# df.head(4)

# %%
df = pd.read_csv('pokemon_data.csv')
df.groupby(['Type 1']).mean().sort_values('Attack',ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
df['count']=1
df.groupby(['Type 1']).count()['count']
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
# ...

# %%
new_df = pd.DataFrame(columns = df.columns)
for df in pd.read_csv('pokemon_data.csv',chunksize = 5):
    
    results = df.groupby(['Type 2']).count()
    new_df = pd.concat([new_df,results])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """
